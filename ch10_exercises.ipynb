# %%
def hangman(word):
    wrong = 0
    stages = ["",
             "________        ",
             "|               ",
             "|        |      ",
             "|        0      ",
             "|       /|\     ",
             "|       / \     ",
             "|               "
              ]
    rletters = list(word)
    board = ["__"] * len(word)
    win = False
    print("Welcome to Hangman")
    while wrong < len(stages) - 1:
        print("\n")
        msg = "Guess a letter"
        char = input(msg)
        if char in rletters:
            cind = rletters.index(char)
            board[cind] = char
            rletters[cind] = '$'
        else:
            wrong += 1
        print((" ".join(board)))
        e = wrong + 1
        print("\n".join(stages[0: e]))
        if "__" not in board:
            print("You win!")
            print(" ".join(board))
            win = True
            break
    if not win:
        print("\n".join(stages[0:wrong]))
        print("You lose! It was {}.".format(word))

hangman("roar")
# Out:
# Welcome to Hangman
#
#
# r __ __ __
#
#
#
# r __ __ __
#
# ________
#
#
# r __ __ __
#
# ________
# |
#
#
# r __ __ r
#
# ________
# |
#
#
# r __ a r
#
# ________
# |
#
#
# r o a r
#
# ________
# |
# You win!
# r o a r

# %%
# 1. Modify the game, so a word is selected randomly from a list of words.

import random

list_of_words = ["roar", "elephant", "plastic", "air"]

a = random.randint(0,len(list_of_words)-1)

hangman(list_of_words[a])
# Out:
# Welcome to Hangman
#
#
# __ __ __ __ __ __ __
#
# ________
#
#
# __ __ __ __ __ __ __
#
# ________
# |
#
#
# __ __ __ __ __ __ __
#
# ________
# |
# |        |
#
#
# __ __ __ __ __ __ __
#
# ________
# |
# |        |
# |        0
#
#
# p __ __ __ __ __ __
#
# ________
# |
# |        |
# |        0
#
#
# p __ a __ __ __ __
#
# ________
# |
# |        |
# |        0
#
#
# p l a __ __ __ __
#
# ________
# |
# |        |
# |        0
#
#
# p l a __ __ __ __
#
# ________
# |
# |        |
# |        0
# |       /|\
#
#
# p l a s __ __ __
#
# ________
# |
# |        |
# |        0
# |       /|\
#
#
# p l a s t __ __
#
# ________
# |
# |        |
# |        0
# |       /|\
#
#
# p l a s t i __
#
# ________
# |
# |        |
# |        0
# |       /|\
#
#
# p l a s t i c
#
# ________
# |
# |        |
# |        0
# |       /|\
# You win!
# p l a s t i c

# %% [markdown]
# Answers

# %%
# 1.

import random


def hangman():
    word_list = ["Python", "Java", "computer", "hacker", "painter"]
    random_number = random.randint(0, 4)
    word = word_list[random_number]
    wrong_guesses = 0
    stages = ["", "________      ", "|      |      ", "|      0      ", "|     /|\     ", "|     / \     ", "|"]
    remaining_letters = list(word)
    letter_board = ["__"] * len(word)
    win = False
    print('Welcome to Hangman')
    while wrong_guesses < len(stages) - 1:
        print('\n')
        guess = input("Guess a letter")
        if guess in remaining_letters:
            character_index = remaining_letters.index(guess)
            letter_board[character_index] = guess
            remaining_letters[character_index] = '$'
        else:
            wrong_guesses += 1
        print((' '.join(letter_board)))
        print('\n'.join(stages[0: wrong_guesses + 1]))
        if '__' not in letter_board:
            print('You win! The word was:')
            print(' '.join(letter_board))
            win = True
            break
    if not win:
        print('\n'.join(stages[0: wrong_guesses]))
        print('You lose! The words was {}'.format(word))

hangman()
